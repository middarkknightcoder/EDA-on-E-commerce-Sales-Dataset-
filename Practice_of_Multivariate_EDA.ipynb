# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ps = pd.read_csv("Sales Product Ecommerce.csv" ,parse_dates=True)
ps
# Out:
#         Order ID                     Product  Quantity Ordered Price Each  \
# 0         236670            Wired Headphones                16      11.99
# 1         236671  Bose SoundSport Headphones                 9      99.99
# 2         236672                      iPhone                 8      700.0
# 3         236673       AA Batteries (4-pack)                12       3.84
# 4         236674       AA Batteries (4-pack)                16       3.84
# ...          ...                         ...               ...        ...
# 185945    319666    Lightning Charging Cable                10      14.95
# 185946    319667       AA Batteries (4-pack)                10       3.84
# 185947    319668             Vareebadd Phone                 5     400,00
# 185948    319669            Wired Headphones                15      11.99
# 185949    319670  Bose SoundSport Headphones                12      99.99
#
#                  Order Date               Customer Shipping Address  \
# ...

# %% [markdown]
# # Check How Long Dataset and also check Datatypes of columns

# %%
ps.head()
# Out:
#    Order ID                     Product  Quantity Ordered Price Each  \
# 0    236670            Wired Headphones                16      11.99
# 1    236671  Bose SoundSport Headphones                 9      99.99
# 2    236672                      iPhone                 8      700.0
# 3    236673       AA Batteries (4-pack)                12       3.84
# 4    236674       AA Batteries (4-pack)                16       3.84
#
#             Order Date             Customer Shipping Address     City Store  \
# 0  2019-08-31 22:21:00      359 Spruce St, Seattle, WA 98101         Dallas
# 1  2019-08-15 15:11:00        492 Ridge St, Dallas, TX 75001    Los Angeles
# 2  2019-08-06 14:40:00        149 7th St, Portland, OR 97035  New York City
# 3  2019-08-29 20:59:00     631 2nd St, Los Angeles, CA 90001  San Francisco
# 4  2019-08-15 19:53:00  736 14th St, New York City, NY 10001         Boston
#
#      Category Customer Gender Customer Age Range Discount
# ...

# %%
ps.sample(5)
# Out:
#         Order ID                   Product  Quantity Ordered Price Each  \
# 45216     283336              Google Phone                 5     600,00
# 127129    259366  Apple Airpods Headphones                 4      150.0
# 149717    212131          Wired Headphones                12      11.99
# 137115    268934      USB-C Charging Cable                20      11.95
# 177605    311655    27in 4K Gaming Monitor                10     389.99
#
#                  Order Date            Customer Shipping Address  \
# 45216   2019-11-08 19:46:00        523 11th St, Boston, MA 02215
# 127129  2019-10-20 11:52:00    955 9th St, Los Angeles, CA 90001
# 149717  2019-06-30 11:11:00        419 10th St, Boston, MA 02215
# 137115  2019-10-07 12:40:00  437 1st St, San Francisco, CA 94016
# 177605  2019-12-07 11:29:00    219 Madison St, Atlanta, GA 30301
#
#            City Store    Category Customer Gender Customer Age Range Discount
# ...

# %%
ps.shape
# Out:
# (185950, 11)

# %%
ps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Order ID                   185950 non-null  int64
#  1   Product                    185950 non-null  object
#  2   Quantity Ordered           185950 non-null  int64
#  3   Price Each                 185950 non-null  object
#  4   Order Date                 185950 non-null  object
#  5   Customer Shipping Address  185950 non-null  object
#  6   City Store                 185950 non-null  object
#  7   Category                   185950 non-null  object
#  8   Customer Gender            185950 non-null  object
#  9   Customer Age Range         185950 non-null  object
#  10  Discount                   185950 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 15.6+ MB

# %% [markdown]
# # Find Missing and Duplicated value into the Dataset

# %%
ps.isnull().sum()
# Out:
# Order ID                     0
# Product                      0
# Quantity Ordered             0
# Price Each                   0
# Order Date                   0
# Customer Shipping Address    0
# City Store                   0
# Category                     0
# Customer Gender              0
# Customer Age Range           0
# Discount                     0
# dtype: int64

# %%
ps.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Find Categoric and Numeric Data Columns sepretly

# %%
psn = ps.select_dtypes(include='number')
# psn = ps.select_dtypes(exclude="object")  Both are same

# %%
psn
# Out:
#         Order ID  Quantity Ordered
# 0         236670                16
# 1         236671                 9
# 2         236672                 8
# 3         236673                12
# 4         236674                16
# ...          ...               ...
# 185945    319666                10
# 185946    319667                10
# 185947    319668                 5
# 185948    319669                15
# 185949    319670                12
#
# [185950 rows x 2 columns]

# %%
psc = ps.select_dtypes(include='object')
psc
# Out:
#                            Product Price Each           Order Date  \
# 0                 Wired Headphones      11.99  2019-08-31 22:21:00
# 1       Bose SoundSport Headphones      99.99  2019-08-15 15:11:00
# 2                           iPhone      700.0  2019-08-06 14:40:00
# 3            AA Batteries (4-pack)       3.84  2019-08-29 20:59:00
# 4            AA Batteries (4-pack)       3.84  2019-08-15 19:53:00
# ...                            ...        ...                  ...
# 185945    Lightning Charging Cable      14.95  2019-12-11 20:58:00
# 185946       AA Batteries (4-pack)       3.84  2019-12-01 12:01:00
# 185947             Vareebadd Phone     400,00   2019-12-09 6:43:00
# 185948            Wired Headphones      11.99  2019-12-03 10:39:00
# 185949  Bose SoundSport Headphones      99.99  2019-12-21 21:45:00
#
#                      Customer Shipping Address     City Store    Category  \
# 0             359 Spruce St, Seattle, WA 98101         Dallas  Headphones
# ...

# %% [markdown]
# # Now we need to perform stastical or mathemetical analysis

# %%
ps.describe()
# Out:
#             Order ID  Quantity Ordered
# count  185950.000000     185950.000000
# mean   230417.569379         10.106948
# std     51512.737110          8.591506
# min    141234.000000          1.000000
# 25%    185831.250000          4.000000
# 50%    230367.500000          8.000000
# 75%    275035.750000         15.000000
# max    319670.000000        180.000000

# %%
ps[["Order ID" ,"Quantity Ordered"]].corr()
# Out:
#                   Order ID  Quantity Ordered
# Order ID          1.000000          0.001714
# Quantity Ordered  0.001714          1.000000

# %%
ps[["Order ID" ,"Quantity Ordered"]].skew()
# Out:
# Order ID            0.000719
# Quantity Ordered    2.762188
# dtype: float64

# %%
sns.distplot(ps["Quantity Ordered"],hist=False)

# Below Graph is represent the Quntity of the Order - We can see that 0 to 25 quntity of order is high.
# Out:
# C:\Users\Ronak\AppData\Local\Temp\ipykernel_8276\2150159808.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ps["Quantity Ordered"],hist=False)
# C:\Users\Ronak\anaconda3\envs\MachineLearning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Quantity Ordered', ylabel='Density'>

# %% [markdown]
# # Now we are convert the Categorical and Numerical Data Columns sepretly

# %%
# THis convertion is base on data understanding :
# If categores into the data is less then column is categorical.
# If Categorys into the data is high then colum is Numerical.

ps.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Customer Shipping Address', 'City Store', 'Category',
#        'Customer Gender', 'Customer Age Range', 'Discount'],
#       dtype='object')

# %%
# ************* Categorical Data Columns

pscat = ps[['Product','City Store', 'Category',
       'Customer Gender']]
pscat
# Out:
#                            Product     City Store    Category Customer Gender
# 0                 Wired Headphones         Dallas  Headphones            Male
# 1       Bose SoundSport Headphones    Los Angeles  Headphones            Male
# 2                           iPhone  New York City       Phone            Male
# 3            AA Batteries (4-pack)  San Francisco   Batteries          Female
# 4            AA Batteries (4-pack)         Boston   Batteries          Female
# ...                            ...            ...         ...             ...
# 185945    Lightning Charging Cable  New York City       Cable          Female
# 185946       AA Batteries (4-pack)  New York City   Batteries          Female
# 185947             Vareebadd Phone  New York City       Phone          Female
# 185948            Wired Headphones  New York City  Headphones            Male
# 185949  Bose SoundSport Headphones  New York City  Headphones          Female
#
# [185950 rows x 4 columns]

# %%
# ************* Numeircal Data Columns

psnum = ps[['Order ID', 'Quantity Ordered', 'Price Each', 'Order Date','Customer Shipping Address', 'Customer Age Range', 'Discount']]

psnum
# Out:
#         Order ID  Quantity Ordered Price Each           Order Date  \
# 0         236670                16      11.99  2019-08-31 22:21:00
# 1         236671                 9      99.99  2019-08-15 15:11:00
# 2         236672                 8      700.0  2019-08-06 14:40:00
# 3         236673                12       3.84  2019-08-29 20:59:00
# 4         236674                16       3.84  2019-08-15 19:53:00
# ...          ...               ...        ...                  ...
# 185945    319666                10      14.95  2019-12-11 20:58:00
# 185946    319667                10       3.84  2019-12-01 12:01:00
# 185947    319668                 5     400,00   2019-12-09 6:43:00
# 185948    319669                15      11.99  2019-12-03 10:39:00
# 185949    319670                12      99.99  2019-12-21 21:45:00
#
#                      Customer Shipping Address Customer Age Range Discount
# 0             359 Spruce St, Seattle, WA 98101              18-20     0,18
# ...

# %% [markdown]
# # How many categories in Categorical Data Columns

# %%
pscat
# Out:
#                            Product     City Store    Category Customer Gender
# 0                 Wired Headphones         Dallas  Headphones            Male
# 1       Bose SoundSport Headphones    Los Angeles  Headphones            Male
# 2                           iPhone  New York City       Phone            Male
# 3            AA Batteries (4-pack)  San Francisco   Batteries          Female
# 4            AA Batteries (4-pack)         Boston   Batteries          Female
# ...                            ...            ...         ...             ...
# 185945    Lightning Charging Cable  New York City       Cable          Female
# 185946       AA Batteries (4-pack)  New York City   Batteries          Female
# 185947             Vareebadd Phone  New York City       Phone          Female
# 185948            Wired Headphones  New York City  Headphones            Male
# 185949  Bose SoundSport Headphones  New York City  Headphones          Female
#
# [185950 rows x 4 columns]

# %%
ps["Product"].value_counts()  # Below Information is tell us which product selling high and which product selling is low
# Out:
# Product
# USB-C Charging Cable          21903
# Lightning Charging Cable      21658
# AAA Batteries (4-pack)        20641
# AA Batteries (4-pack)         20577
# Wired Headphones              18882
# Apple Airpods Headphones      15549
# Bose SoundSport Headphones    13325
# 27in FHD Monitor               7507
# iPhone                         6842
# 27in 4K Gaming Monitor         6230
# 34in Ultrawide Monitor         6181
# Google Phone                   5525
# Flatscreen TV                  4800
# Macbook Pro Laptop             4724
# ThinkPad Laptop                4128
# 20in Monitor                   4101
# Vareebadd Phone                2065
# LG Washing Machine              666
# LG Dryer                        646
# Name: count, dtype: int64

# %%
ps["City Store"].value_counts()  # We can see that which "city people" is buying high online 

# Here we can see that "Dallas" City public most order in ecomerce
# Out:
# City Store
# Dallas           38044
# New York City    37119
# San Francisco    37099
# Los Angeles      36849
# Boston           36839
# Name: count, dtype: int64

# %%
ps["Customer Gender"].value_counts()  # Here we can see that Female is more shoipng online with compare to male.
# Out:
# Customer Gender
# Female    106257
# Male       79693
# Name: count, dtype: int64

# %%
ps["Category"].value_counts()
# Out:
# Category
# Headphones    47756
# Cable         43561
# Batteries     41218
# Monitor       24019
# Phone         14432
# Laptop         8852
# TV             4800
# Machine         666
# Dryer           646
# Name: count, dtype: int64

# %% [markdown]
# # ***************** Univariate Analysis on Dataset  *****************

# %%
pscat
# Out:
#                            Product     City Store    Category Customer Gender
# 0                 Wired Headphones         Dallas  Headphones            Male
# 1       Bose SoundSport Headphones    Los Angeles  Headphones            Male
# 2                           iPhone  New York City       Phone            Male
# 3            AA Batteries (4-pack)  San Francisco   Batteries          Female
# 4            AA Batteries (4-pack)         Boston   Batteries          Female
# ...                            ...            ...         ...             ...
# 185945    Lightning Charging Cable  New York City       Cable          Female
# 185946       AA Batteries (4-pack)  New York City   Batteries          Female
# 185947             Vareebadd Phone  New York City       Phone          Female
# 185948            Wired Headphones  New York City  Headphones            Male
# 185949  Bose SoundSport Headphones  New York City  Headphones          Female
#
# [185950 rows x 4 columns]

# %%
psnum
# Out:
#         Order ID  Quantity Ordered Price Each           Order Date  \
# 0         236670                16      11.99  2019-08-31 22:21:00
# 1         236671                 9      99.99  2019-08-15 15:11:00
# 2         236672                 8      700.0  2019-08-06 14:40:00
# 3         236673                12       3.84  2019-08-29 20:59:00
# 4         236674                16       3.84  2019-08-15 19:53:00
# ...          ...               ...        ...                  ...
# 185945    319666                10      14.95  2019-12-11 20:58:00
# 185946    319667                10       3.84  2019-12-01 12:01:00
# 185947    319668                 5     400,00   2019-12-09 6:43:00
# 185948    319669                15      11.99  2019-12-03 10:39:00
# 185949    319670                12      99.99  2019-12-21 21:45:00
#
#                      Customer Shipping Address Customer Age Range Discount
# 0             359 Spruce St, Seattle, WA 98101              18-20     0,18
# ...

# %% [markdown]
# # **** Perform Eda on Categorical data

# %%
pscat
# Out:
#                            Product     City Store    Category Customer Gender
# 0                 Wired Headphones         Dallas  Headphones            Male
# 1       Bose SoundSport Headphones    Los Angeles  Headphones            Male
# 2                           iPhone  New York City       Phone            Male
# 3            AA Batteries (4-pack)  San Francisco   Batteries          Female
# 4            AA Batteries (4-pack)         Boston   Batteries          Female
# ...                            ...            ...         ...             ...
# 185945    Lightning Charging Cable  New York City       Cable          Female
# 185946       AA Batteries (4-pack)  New York City   Batteries          Female
# 185947             Vareebadd Phone  New York City       Phone          Female
# 185948            Wired Headphones  New York City  Headphones            Male
# 185949  Bose SoundSport Headphones  New York City  Headphones          Female
#
# [185950 rows x 4 columns]

# %%
ps["Product"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Product'>

# %%
ps["Product"].value_counts().plot(kind="pie",autopct="%.2f" ,title="Products")
# Out:
# <Axes: title={'center': 'Products'}, ylabel='count'>

# %%
ps["City Store"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='City Store'>

# %%
ps["City Store"].value_counts().plot(kind="pie",autopct="%.2f",title="City Store")

plt.show()

# %%
ps["Category"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Category'>

# %%
ps["Category"].value_counts().plot(kind="pie",autopct="%.2f",title="Product Categorys")
plt.show()

# %% [markdown]
# # **** Perform Eda on Numerical Data

# %%
psnum
# Out:
#         Order ID  Quantity Ordered Price Each           Order Date  \
# 0         236670                16      11.99  2019-08-31 22:21:00
# 1         236671                 9      99.99  2019-08-15 15:11:00
# 2         236672                 8      700.0  2019-08-06 14:40:00
# 3         236673                12       3.84  2019-08-29 20:59:00
# 4         236674                16       3.84  2019-08-15 19:53:00
# ...          ...               ...        ...                  ...
# 185945    319666                10      14.95  2019-12-11 20:58:00
# 185946    319667                10       3.84  2019-12-01 12:01:00
# 185947    319668                 5     400,00   2019-12-09 6:43:00
# 185948    319669                15      11.99  2019-12-03 10:39:00
# 185949    319670                12      99.99  2019-12-21 21:45:00
#
#                      Customer Shipping Address Customer Age Range Discount
# 0             359 Spruce St, Seattle, WA 98101              18-20     0,18
# ...

# %%
sns.histplot(psnum["Price Each"].head(100),bins=100,binwidth=0.5)
plt.show()
# Out:
# C:\Users\Ronak\anaconda3\envs\MachineLearning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# sns.boxplot(psnum["Price Each"]) Here you can not used Boxplot because column is not contain Numeric data

# %%
psnum["Price Each"].max()
# Out:
# '999.99'

# %%
psnum["Price Each"].min()
# Out:
# '1.700,00'

# %%
sns.histplot(psnum["Quantity Ordered"],binwidth=5.5,bins=50)
# Out:
# C:\Users\Ronak\anaconda3\envs\MachineLearning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Quantity Ordered', ylabel='Count'>

# %%
sns.distplot(psnum["Quantity Ordered"],hist=False)
# Out:
# C:\Users\Ronak\AppData\Local\Temp\ipykernel_25120\750341528.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(psnum["Quantity Ordered"],hist=False)
# C:\Users\Ronak\anaconda3\envs\MachineLearning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Quantity Ordered', ylabel='Density'>

# %%
sns.boxplot(psnum["Quantity Ordered"])  

# Here we can see that in Quntity Order Otluer order is very high.
# Out:
# <Axes: >

# %% [markdown]
# # **************** Bivariate and Multivariate Analysis ****************

# %%
pscat
# Out:
#                            Product     City Store    Category Customer Gender
# 0                 Wired Headphones         Dallas  Headphones            Male
# 1       Bose SoundSport Headphones    Los Angeles  Headphones            Male
# 2                           iPhone  New York City       Phone            Male
# 3            AA Batteries (4-pack)  San Francisco   Batteries          Female
# 4            AA Batteries (4-pack)         Boston   Batteries          Female
# ...                            ...            ...         ...             ...
# 185945    Lightning Charging Cable  New York City       Cable          Female
# 185946       AA Batteries (4-pack)  New York City   Batteries          Female
# 185947             Vareebadd Phone  New York City       Phone          Female
# 185948            Wired Headphones  New York City  Headphones            Male
# 185949  Bose SoundSport Headphones  New York City  Headphones          Female
#
# [185950 rows x 4 columns]

# %%
psnum
# Out:
#         Order ID  Quantity Ordered Price Each           Order Date  \
# 0         236670                16      11.99  2019-08-31 22:21:00
# 1         236671                 9      99.99  2019-08-15 15:11:00
# 2         236672                 8      700.0  2019-08-06 14:40:00
# 3         236673                12       3.84  2019-08-29 20:59:00
# 4         236674                16       3.84  2019-08-15 19:53:00
# ...          ...               ...        ...                  ...
# 185945    319666                10      14.95  2019-12-11 20:58:00
# 185946    319667                10       3.84  2019-12-01 12:01:00
# 185947    319668                 5     400,00   2019-12-09 6:43:00
# 185948    319669                15      11.99  2019-12-03 10:39:00
# 185949    319670                12      99.99  2019-12-21 21:45:00
#
#                      Customer Shipping Address Customer Age Range Discount
# 0             359 Spruce St, Seattle, WA 98101              18-20     0,18
# ...

# %% [markdown]
# # 1. Scatterplot (Numerical - Numerical) Data
#
# ### ScatterPlot is usde for the compare the two columns.

# %%
sns.scatterplot(data=ps.head(100), x="Order Date" ,y="Quantity Ordered",hue="Customer Age Range",style="Customer Gender")
# Out:
# <Axes: xlabel='Order Date', ylabel='Quantity Ordered'>

# %%
sns.scatterplot(data=ps,x="Price Each" ,y="Discount")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 2. pairplot (Numerical - Categorical) data Columns

# %%
sns.pairplot(ps.head(200),hue="Customer Gender")
# Out:
# C:\Users\Ronak\anaconda3\envs\MachineLearning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ronak\anaconda3\envs\MachineLearning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # 3. relplot (Numerical- Categorical)

# %%
sns.relplot(data=ps.head(100), x="Order Date" ,y="Quantity Ordered",hue="Customer Age Range",col="Customer Gender",kind="scatter")

# %% [markdown]
# # 4. barplot (Numerical - Categorical) Data columns

# %%
ps
# Out:
#         Order ID                     Product  Quantity Ordered Price Each  \
# 0         236670            Wired Headphones                16      11.99
# 1         236671  Bose SoundSport Headphones                 9      99.99
# 2         236672                      iPhone                 8      700.0
# 3         236673       AA Batteries (4-pack)                12       3.84
# 4         236674       AA Batteries (4-pack)                16       3.84
# ...          ...                         ...               ...        ...
# 185945    319666    Lightning Charging Cable                10      14.95
# 185946    319667       AA Batteries (4-pack)                10       3.84
# 185947    319668             Vareebadd Phone                 5     400,00
# 185948    319669            Wired Headphones                15      11.99
# 185949    319670  Bose SoundSport Headphones                12      99.99
#
#                  Order Date               Customer Shipping Address  \
# ...

# %%
sns.barplot(data=ps,x="Category" ,y="Quantity Ordered",hue="Customer Age Range")
plt.legend(loc=1)

# Here we can see that most Quantity order is "Battries" age wise shoping information.

# %%
sns.barplot(data=ps,x="Category" ,y="Quantity Ordered",hue="Customer Gender")
plt.legend(loc=1)

# %%
# sns.barplot(data=ps,x="Category" ,y="Price Each") This is not valid

sns.barplot(data=ps,x="City Store" ,y="Quantity Ordered",hue="Customer Gender")
# Out:
# <Axes: xlabel='City Store', ylabel='Quantity Ordered'>

# %%
sns.barplot(data=ps,x="Product" ,y="Quantity Ordered",hue="Customer Gender")
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(data=ps,x="Customer Gender" ,y="Quantity Ordered")
# Out:
# <Axes: xlabel='Customer Gender', ylabel='Quantity Ordered'>

# %% [markdown]
# # 5. boxplot (Numerical -Categorical) Data Columns

# %%
ps
# Out:
#         Order ID                     Product  Quantity Ordered Price Each  \
# 0         236670            Wired Headphones                16      11.99
# 1         236671  Bose SoundSport Headphones                 9      99.99
# 2         236672                      iPhone                 8      700.0
# 3         236673       AA Batteries (4-pack)                12       3.84
# 4         236674       AA Batteries (4-pack)                16       3.84
# ...          ...                         ...               ...        ...
# 185945    319666    Lightning Charging Cable                10      14.95
# 185946    319667       AA Batteries (4-pack)                10       3.84
# 185947    319668             Vareebadd Phone                 5     400,00
# 185948    319669            Wired Headphones                15      11.99
# 185949    319670  Bose SoundSport Headphones                12      99.99
#
#                  Order Date               Customer Shipping Address  \
# ...

# %%
sns.boxplot(data=ps ,x="City Store" ,y="Quantity Ordered")  

# Here we can see "San Franciso" peopeple Quantity orderd is "more outlier"
# Out:
# <Axes: xlabel='City Store', ylabel='Quantity Ordered'>

# %%
sns.boxplot(data=ps ,x="City Store" ,y="Quantity Ordered" ,hue="Customer Gender")  
plt.title("Quantity of Orderd City Wise")
# Below Graph is repersent the man and Female Orderd Quantity city wise.
# Out:
# Text(0.5, 1.0, 'Quantity of Orderd City Wise')

# %%
sns.boxplot(data=ps ,x="Category" ,y="Quantity Ordered" ,hue="Customer Gender")  
plt.title("Quantity of Orderd City Wise")

# In Below Garph we can see that Battries most outlier in Quantity ordered and also In Female Outlier is most.
# Out:
# Text(0.5, 1.0, 'Quantity of Orderd City Wise')

# %% [markdown]
# # 6. distplot (Numerical-Categorical) data columns
#
# ### We know Distplot is only contain One Column Value.

# %%
sns.distplot(ps[ps["Customer Gender"] == "Male"]["Quantity Ordered"],hist=False)
sns.distplot(ps[ps["Customer Gender"] == "Female"]["Quantity Ordered"],hist=False)

# In Below Graph we can see thet Quantity Distribution of MAle and Female ara similar.
# probaility is high Between 0 to 25 orderd Quantity in online Shoping.
# Out:
# C:\Users\Ronak\AppData\Local\Temp\ipykernel_10880\1431927176.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ps[ps["Customer Gender"] == "Male"]["Quantity Ordered"],hist=False)
# C:\Users\Ronak\anaconda3\envs\MachineLearning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ronak\AppData\Local\Temp\ipykernel_10880\1431927176.py:2: UserWarning:
#
# ...

# %%
ps["Category"].value_counts()
# Out:
# Category
# Headphones    47756
# Cable         43561
# Batteries     41218
# Monitor       24019
# Phone         14432
# Laptop         8852
# TV             4800
# Machine         666
# Dryer           646
# Name: count, dtype: int64

# %%
sns.distplot(ps[ps["Category"] == "Headphones"]["Quantity Ordered"],hist=False)
sns.distplot(ps[ps["Category"] == "Cable"]["Quantity Ordered"],hist=False)
sns.distplot(ps[ps["Category"] == "Batteries"]["Quantity Ordered"],hist=False)
sns.distplot(ps[ps["Category"] == "Monitor"]["Quantity Ordered"],hist=False)
sns.distplot(ps[ps["Category"] == "Phone"]["Quantity Ordered"],hist=False)
sns.distplot(ps[ps["Category"] == "Laptop"]["Quantity Ordered"],hist=False)
sns.distplot(ps[ps["Category"] == "TV"]["Quantity Ordered"],hist=False)
sns.distplot(ps[ps["Category"] == "Machine"]["Quantity Ordered"],hist=False)
sns.distplot(ps[ps["Category"] == "Dryer"]["Quantity Ordered"],hist=False)


# sns.histplot(ps[ps["Category"] == "Headphones"]["Quantity Ordered"] ,binwidth=2, legend=True)
# sns.histplot(ps[ps["Category"] == "Cable"]["Quantity Ordered"] ,binwidth=2, legend=True)
# sns.histplot(ps[ps["Category"] == "Batteries"]["Quantity Ordered"] ,binwidth=2, legend=True)
# sns.histplot(ps[ps["Category"] == "Monitor"]["Quantity Ordered"] ,binwidth=2, legend=True)
# sns.histplot(ps[ps["Category"] == "Phone"]["Quantity Ordered"] ,binwidth=2, legend=True)
# sns.histplot(ps[ps["Category"] == "Laptop"]["Quantity Ordered"] ,binwidth=2, legend=True)
# sns.histplot(ps[ps["Category"] == "TV"]["Quantity Ordered"] ,binwidth=2, legend=True)
# sns.histplot(ps[ps["Category"] == "Machine"]["Quantity Ordered"] ,binwidth=2, legend=True)
# sns.histplot(ps[ps["Category"] == "Dryer"]["Quantity Ordered"] ,binwidth=2, legend=True)
# Out:
# C:\Users\Ronak\AppData\Local\Temp\ipykernel_10880\2944865975.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ps[ps["Category"] == "Headphones"]["Quantity Ordered"],hist=False)
# C:\Users\Ronak\anaconda3\envs\MachineLearning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ronak\AppData\Local\Temp\ipykernel_10880\2944865975.py:2: UserWarning:
#
# ...

# %% [markdown]
# # 7. heatmap (Categorical - Categorical) Data Columns.
#
# ### Heatmap is create graph between the categorical data columns when If possible to create table of two columns

# %%
pscat
# Out:
#                            Product     City Store    Category Customer Gender
# 0                 Wired Headphones         Dallas  Headphones            Male
# 1       Bose SoundSport Headphones    Los Angeles  Headphones            Male
# 2                           iPhone  New York City       Phone            Male
# 3            AA Batteries (4-pack)  San Francisco   Batteries          Female
# 4            AA Batteries (4-pack)         Boston   Batteries          Female
# ...                            ...            ...         ...             ...
# 185945    Lightning Charging Cable  New York City       Cable          Female
# 185946       AA Batteries (4-pack)  New York City   Batteries          Female
# 185947             Vareebadd Phone  New York City       Phone          Female
# 185948            Wired Headphones  New York City  Headphones            Male
# 185949  Bose SoundSport Headphones  New York City  Headphones          Female
#
# [185950 rows x 4 columns]

# %%
ps["Category"].value_counts()
# Out:
# Category
# Headphones    47756
# Cable         43561
# Batteries     41218
# Monitor       24019
# Phone         14432
# Laptop         8852
# TV             4800
# Machine         666
# Dryer           646
# Name: count, dtype: int64

# %%
# pd.crosstab(ps["City Store"] ,ps["Category"]).max()
pd.crosstab(ps["City Store"] ,ps["Category"])
# Out:
# Category       Batteries  Cable  Dryer  Headphones  Laptop  Machine  Monitor  \
# City Store
# Boston              8139   8643    117        9508    1700      122     4750
# Dallas              8445   8897    120        9820    1812      141     4942
# Los Angeles         8175   8546    136        9475    1754      133     4789
# New York City       8138   8739    146        9457    1797      146     4784
# San Francisco       8321   8736    127        9496    1789      124     4754
#
# Category       Phone   TV
# City Store
# Boston          2877  983
# Dallas          2914  953
# Los Angeles     2899  942
# New York City   2922  990
# San Francisco   2820  932

# %%
sns.heatmap(pd.crosstab(ps["City Store"] ,ps["Category"]))
# Out:
# <Axes: xlabel='Category', ylabel='City Store'>

# %%
pd.crosstab(ps["Customer Gender"],ps["Category"])
# Out:
# Category         Batteries  Cable  Dryer  Headphones  Laptop  Machine  \
# Customer Gender
# Female               23703  24906    372       27104    5017      390
# Male                 17515  18655    274       20652    3835      276
#
# Category         Monitor  Phone    TV
# Customer Gender
# Female             13868   8176  2721
# Male               10151   6256  2079

# %%
sns.heatmap(pd.crosstab(ps["Customer Gender"],ps["Category"]))
plt.show()

# %%
ps.groupby("Category")["Quantity Ordered"].mean().plot(kind="pie")
# Out:
# <Axes: ylabel='Quantity Ordered'>

# %% [markdown]
# # 8. clustermap ( Categorical - Categorical) Data Columns
#
# ### Clustermap is reperent the crosstable in color form and also reperent the relation between the category.
# ### Relation is represent in hirarcial form.

# %%
pd.crosstab(ps["Customer Gender"],ps["Category"])

# %%
sns.clustermap(pd.crosstab(ps["Customer Gender"],ps["Category"]))


# Here we can see  relation between the category of product with specified Gender.

# %%
sns.clustermap(pd.crosstab(ps["City Store"] ,ps["Category"]) ,annot=True,figsize=(12, 12))

# %% [markdown]
# # 9. Lineplot (Numerical - Numerical) Data Columns

# %%
sns.lineplot(data=ps.head(100) ,y="Customer Age Range",x="Quantity Ordered",hue="Category")
plt.legend(loc=1)

# This Chart represnt the Headphone and Phone is buying more by 18 to 35 years old people.
# Out:
# C:\Users\Ronak\anaconda3\envs\MachineLearning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ronak\anaconda3\envs\MachineLearning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
